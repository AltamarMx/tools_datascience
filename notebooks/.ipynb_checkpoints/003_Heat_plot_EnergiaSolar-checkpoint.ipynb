# %% [raw]
# ---
# title: "003 Heat plot energía solar"
# format:
#   html:
#     code-fold: False
# jupyter: python3
# ---

# %%
# pip install calplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import calplot

# %%
f = '../data/tmx.csv'
data = pd.read_csv(f,index_col=0,parse_dates=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
calplot.calplot(data.To,how='sum',cmap='jet',colorbar=True)
# Out:
# (<Figure size 1250x170 with 2 Axes>,
#  array([<Axes: ylabel='2023'>], dtype=object))
